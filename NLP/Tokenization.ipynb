# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /Users/interlink/Desktop/ML_PYTHON_01/venv/lib/python3.12/site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /Users/interlink/Desktop/ML_PYTHON_01/venv/lib/python3.12/site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.2.28-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Downloading nltk-3.9.3-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 294.0 kB/s eta 0:00:00a 0:00:01
# Downloading regex-2026.2.28-cp312-cp312-macosx_11_0_arm64.whl (289 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, nltk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [nltk]2/3 [nltk]
# Successfully installed nltk-3.9.3 regex-2026.2.28 tqdm-4.67.3

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/interlink/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/interlink/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
dcorpus = """Hello, Welcome to NLP. My name is Rasheed Ahmad. I am ML Engineer.
Student of Artifical Intelligence at Comsats University.
"""

# %%
print(corpus)
# Out:
#     Hello, Welcome to NLP. My name is Rasheed Ahmad. I am ML Engineer.
#     Student of Artifical Intelligence at Comsats University.

# %% [markdown]
# ## Tokenization
# ### Corpus(Paragraph) --> Document(Sentence)

# %%
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
print(documents)
# Out:
# ['\n    Hello, Welcome to NLP.', 'My name is Rasheed Ahmad.', 'I am ML Engineer.', 'Student of Artifical Intelligence at Comsats University.']

# %%
for sentence in documents:
    print(sentence)
# Out:
#     Hello, Welcome to NLP.
# My name is Rasheed Ahmad.
# I am ML Engineer.
# Student of Artifical Intelligence at Comsats University.

# %% [markdown]
# ## Tokenization
# ## Paragraph-->words
# ## sentence--->words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'NLP',
#  '.',
#  'My',
#  'name',
#  'is',
#  'Rasheed',
#  'Ahmad',
#  '.',
#  'I',
#  'am',
#  'ML',
#  'Engineer',
#  '.',
#  'Student',
#  'of',
#  'Artifical',
#  'Intelligence',
#  'at',
#  'Comsats',
#  'University',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', ',', 'Welcome', 'to', 'NLP', '.']
# ['My', 'name', 'is', 'Rasheed', 'Ahmad', '.']
# ['I', 'am', 'ML', 'Engineer', '.']
# ['Student', 'of', 'Artifical', 'Intelligence', 'at', 'Comsats', 'University', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'NLP',
#  '.',
#  'My',
#  'name',
#  'is',
#  'Rasheed',
#  'Ahmad',
#  '.',
#  'I',
#  'am',
#  'ML',
#  'Engineer',
#  '.',
#  'Student',
#  'of',
#  'Artifical',
#  'Intelligence',
#  'at',
#  'Comsats',
#  'University',
#  '.']

# %%
from nltk.tokenize import TreebankWordDetokenizer

# %%
tokenizer = TreebankWordDetokenizer()

# %%
tokenizer.tokenize(documents)
# Out:
# 'Hello, Welcome to NLP. My name is Rasheed Ahmad. I am ML Engineer. Student of Artifical Intelligence at Comsats University.'
